# %%
from ultralytics import YOLO
model  = YOLO("yolov8m.pt")

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA device count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")

# %%
result = model.train(data='/kaggle/input/vehicle-day/data.yaml', 
                    epochs=100,           # Increased for better convergence
                    imgsz=1280, 
                    batch=16,             # Effective batch size of 64 with 2 GPUs
                    device=[0, 1]
                    )

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.203 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#                                                        CUDA:1 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 67.7±16.9 MB/s, size: 78.7 KB)
# val: Scanning /kaggle/input/vehicle-day/valid/labels... 1077 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1077/1077 398.5it/s 2.7s0.0s
# val: /kaggle/input/vehicle-day/valid/images/cam_01_00961_jpg.rf.43490c6e7215b6442df17b7ec1e8496c.jpg: 1 duplicate labels removed
# val: /kaggle/input/vehicle-day/valid/images/cam_04_00018_jpg.rf.3df96347d29b4f49a79e61860210158b.jpg: 1 duplicate labels removed
# val: /kaggle/input/vehicle-day/valid/images/cam_04_00022_jpg.rf.ff1ebe40784c4fb91f2c97365cc5a4be.jpg: 1 duplicate labels removed
# val: /kaggle/input/vehicle-day/valid/images/cam_04_00328_jpg.rf.11487bb1b5bca1171e0152add77e895c.jpg: 1 duplicate labels removed
# val: /kaggle/input/vehicle-day/valid/images/cam_04_00915_jpg.rf.1ced7f5bb5178b07a612a805ce53e06b.jpg: 1 duplicate labels removed
# val: /kaggle/input/vehicle-day/valid/images/cam_06_00803_jpg.rf.95baca4e0a8a4542a01f8b278e41324f.jpg: 1 duplicate labels removed
# WARNING ⚠️ val: Cache directory /kaggle/input/vehicle-day/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 68/68 1.3it/s 53.7s0.8ss
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all       1077      15571      0.901      0.914      0.946      0.683
#                      0       1014      10331      0.903       0.92      0.959      0.608
#                      1        810       2759      0.905      0.925      0.953      0.681
#                      2        408        630      0.909      0.898      0.931      0.738
#                      3        701       1851      0.888       0.91       0.94      0.704
# Speed: 0.5ms preprocess, 45.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train23

# %%
overall_metrics = metrics.results_dict

# %%
per_class_metrics = {
    'Class': [metrics.names[i] for i in metrics.ap_class_index],
    'Precision': metrics.box.p,
    'Recall': metrics.box.r,
    'mAP50': metrics.box.map50,
    'mAP50-95': metrics.box.map
}

# %%
import pandas as pd
overall_df = pd.DataFrame([overall_metrics])
per_class_df = pd.DataFrame(per_class_metrics)

# %%
overall_df.to_csv('overall_metrics.csv', index=False)
per_class_df.to_csv('per_class_metrics.csv', index=False)

print("Validation results saved to overall_metrics.csv and per_class_metrics.csv")
# Out:
# Validation results saved to overall_metrics.csv and per_class_metrics.csv
